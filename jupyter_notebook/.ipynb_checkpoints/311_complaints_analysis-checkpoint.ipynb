# %% [markdown]
# First, load the 311 complaints dataset available here https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9

# %%
##download CSV directly from open data and stream process into typed array
##do this scalably so that i can bring this notebook to private data office in new york in a year and revolutionize how cities are built to be more harmonious with our true nature of multi-generational households and hybrid work                                                                                                                                                                                                               nn
#correct market inefficencies + information assymetries + change cities + noisy homes that cause insomnia with accurate data visualizations with zero cognitive load and positive and light valence
uri = 'https://data.sfgov.org/City-Infrastructure/311-Cases/vw6y-z8j6#:~:text=in%20other%20applications.-,CSV,-CSV%20for%20Excel'


##download SF Data and NYC data and generalize across both into maps for nbdev and export into book of shaders

# %%
CSV_PATH = './311_Service_Requests_from_2010_to_Present.csv'
import subprocess
from tqdm import tqdm
import pandas as pd 
import os
from h3 import h3
import warnings
warnings.filterwarnings('ignore')


def file_len(fname):
    p = subprocess.Popen(['wc', '-l', fname], stdout=subprocess.PIPE, 
                                              stderr=subprocess.PIPE)
    result, err = p.communicate()
    if p.returncode != 0:
        raise IOError(err)
    return int(result.strip().split()[0])+1

n_rows = file_len(CSV_PATH)
print (f'Exact number of rows: {n_rows}')
df_tmp = pd.read_csv(CSV_PATH, nrows=5)
df_tmp.head()

#import h3 fix !!!!!!
# Out:
# Exact number of rows: 31852575
#    Unique Key            Created Date             Closed Date Agency  \
# 0    19401582  12/22/2010 02:14:47 AM  12/22/2010 05:23:35 AM   NYPD
# 1    19401583  12/22/2010 02:23:27 AM  12/22/2010 04:38:17 AM   NYPD
# 2    19401584  12/22/2010 03:16:06 AM  12/22/2010 04:36:16 AM   NYPD
# 3    19401585  12/22/2010 03:41:08 AM  12/22/2010 03:45:32 PM   NYPD
# 4    19401587  12/22/2010 08:48:06 AM  12/29/2010 09:06:35 AM    DOT
#
#                        Agency Name         Complaint Type        Descriptor  \
# 0  New York City Police Department    Noise - Residential  Loud Music/Party
# 1  New York City Police Department       Blocked Driveway    Partial Access
# 2  New York City Police Department     Noise - Commercial  Loud Music/Party
# 3  New York City Police Department    Noise - Residential  Banging/Pounding
# 4     Department of Transportation  Street Sign - Damaged              Stop
#
# ...

# %%
types = {
    #'Unique Key': 'float32',
              'Complaint Type': 'category', 
              'Longitude': 'float32',
              'Latitude': 'float32',
#              'Incident Zip': 'int',
#              'Created Date': 'str',
#              'Closed Date': 'str',
        }
cols = list(types.keys())
chunksize = 5_000_000

df_list = [] # list to hold the batch dataframe

def process_date(df_chunk, key):
    df_chunk[key] = df_chunk[key].str.slice(0, 16)
    #df_chunk[key] = pd.to_datetime(df_chunk[key], utc=True, format='%Y-%m-%d %H:%M')
    
for df_chunk in tqdm(pd.read_csv(CSV_PATH, usecols=cols, dtype=types, chunksize=chunksize)):
    # Neat trick from https://www.kaggle.com/btyuhas/bayesian-optimization-with-xgboost
    # Using parse_dates would be much slower!
    #    process_date(df_chunk, 'Closed Date')
    #    process_date(df_chunk, 'Created Date')
    df_list.append(df_chunk) 

    
pdf = pd.concat(df_list)

# Delete the dataframe list to release memory
del df_list

# See what we have loaded
pdf.info()
#takes 1:30 minutes
# Out:
# 7it [01:29, 12.80s/it]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31852573 entries, 0 to 31852572
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Complaint Type  object
#  1   Latitude        float32
#  2   Longitude       float32
# dtypes: float32(2), object(1)
# memory usage: 486.0+ MB

# %%
pd.options.display.max_rows = 2000

counts = pdf['Complaint Type'].value_counts()
print(counts)
# Out:
#                                53404
# HPD Literature Request                         52831
# Illegal Fireworks                              52453
# Dead/Dying Tree                                52312
# Animal Abuse                                   52178
# Housing - Low Income Senior                    51517
# Curb Condition                                 49611
# Indoor Air Quality                             49304
# Vending                                        46600
# Highway Condition                              45229
# Emergency Response Team (ERT)                  44840
# Traffic                                        44684
# Noise - Park                                   42877
# Water Conservation                             42085
# Special Projects Inspection Team (SPIT)        41428
# DHS Advantage - Tenant                         40930
# Homeless Encampment                            38208
# Electrical                                     38070
# ...

# %%
###rank neighborhoods or zip codes by their most prominent complaint type
###output of this notebook is hexagonall binned hardcoded but i want two outputs
###flat list unbinned to do the binning in the shader to be more dynamic to update the feature selections more adaptive to user input so they can select it with voice and build multiple selects that get compiled down 
#output = list of JSON to be processed into Array of tuples[zipcode, long, lat, complaintType, complaintText for search



#cool trick to start from optimal user behavior / thought to implementation details in layers to find shortest path

APERTURE_SIZE = 9
hex_col = 'hex'+str(APERTURE_SIZE)


pdf[hex_col] = 0
import json

print(1)
def binRow(df311):
    # find hexs containing the points
    df311[hex_col] = df311.apply(lambda x: h3.geo_to_h3(x.Latitude,x.Longitude,APERTURE_SIZE),1)

    # aggregate the points
    df311g = df311.groupby(hex_col).size()#.to_frame('cnt').reset_index()

    #find center of hex for visualization
#     df311g['lat'] = df311g[hex_col].apply(lambda x: h3.h3_to_geo(x)[0])
#     df311g['lng'] = df311g[hex_col].apply(lambda x: h3.h3_to_geo(x)[1])
    return (df311g)


def saveComplaint(complaint):
    print(complaint)
    data = pdf.loc[pdf['Complaint Type'] ==(complaint)]
    binned = binRow(data)
    complaint = complaint.replace(' ', '-').replace('/','-')
    hi = [(hex, count)  for hex,count in binned.iteritems()]
    with open('./data/'+complaint+'.json', 'w') as outfile: json.dump(hi, outfile)
    
stuff = ['Noise - Residential',                         
'HEAT/HOT WATER' ,                              
'Street Condition'   ,                           
'Illegal Parking ',                              
'Blocked Driveway'  ,                            
'Street Light Condition' ,                       
'HEATING'          ,                             
'PLUMBING'     ,                                 
'Water System'  ,                                
'Noise - Street/Sidewalk' ,                      
'GENERAL CONSTRUCTION'  ,                                                                
'UNSANITARY CONDITION']                          
for complaint in stuff:
    saveComplaint(complaint)
# Out:
# 1
# Noise - Residential
# HEAT/HOT WATER
# Street Condition
# Illegal Parking
# Blocked Driveway
# Street Light Condition
# HEATING
# PLUMBING
# Water System
# Noise - Street/Sidewalk
# GENERAL CONSTRUCTION
# UNSANITARY CONDITION

# %%
# data = pdf.loc[pdf['Complaint Type'] ==('Noise - Residential')]
# binned = binRow(data)
for hex, row in binned.iteritems():
    print(hex, row)
# Out:
# 0 6593
# 872a10000ffffff 198
# 872a10002ffffff 216
# 872a10003ffffff 423
# 872a10006ffffff 2
# 872a10009ffffff 143
# 872a1000affffff 169
# 872a1000bffffff 1260
# 872a10010ffffff 25937
# 872a10011ffffff 6488
# 872a10012ffffff 54626
# 872a10013ffffff 32454
# 872a10014ffffff 14472
# 872a10015ffffff 2893
# 872a10016ffffff 18496
# 872a10018ffffff 5972
# 872a10019ffffff 1443
# 872a1001affffff 16976
# 872a1001bffffff 1492
# 872a1001cffffff 5469
# 872a1001dffffff 4347
# 872a1001effffff 25995
# 872a10033ffffff 67
# 872a10042ffffff 628
# 872a10046ffffff 23
# 872a10050ffffff 953
# 872a10051ffffff 3818
# 872a10052ffffff 1627
# 872a10053ffffff 3547
# 872a10054ffffff 508
# 872a10055ffffff 947
# 872a10056ffffff 1434
# 872a10058ffffff 1705
# 872a10059ffffff 156
# 872a1005affffff 4679
# 872a1005bffffff 2916
# 872a1005cffffff 327
# 872a1005effffff 6993
# 872a10073ffffff 9
# 872a10088ffffff 25697
# 872a10089ffffff 20769
# 872a1008bffffff 10205
# 872a1008cffffff 36002
# 872a1008dffffff 55584
# ...

# %%
#todo download visualize value instagram portfolio and upload visualize-mind-magic


#observe mind while playing with data to avoid distraction
#understanding is seeing how puzzle pieces fit together
#observe mind while writing software that writes data into other people's mind software
